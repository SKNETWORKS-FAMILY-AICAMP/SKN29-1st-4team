# %%
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='!didwjdgus16',
    database='car_insurance_final',
    charset='utf8mb4'
)
cursor = conn.cursor()

insert_sql = """
INSERT INTO insurance_product (insurance_product_name)
VALUES (%s)
ON DUPLICATE KEY UPDATE
    insurance_product_name = VALUES(insurance_product_name)
"""

data_to_insert = [
    ('개인용',),
    ('업무용',),
    ('영업용',)
]

cursor.executemany(insert_sql, data_to_insert)
conn.commit()

print(f"{cursor.rowcount}건 처리 완료")

cursor.execute("SELECT * FROM insurance_product")
for row in cursor.fetchall():
    print(row)

cursor.close()
conn.close()
# Out:
# 3건 처리 완료
# (1, '개인용')
# (2, '업무용')
# (3, '영업용')
