# %%
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='!didwjdgus16',
    database='car_insurance_final',
    charset='utf8mb4'
)
cursor = conn.cursor()

insert_sql = """
INSERT INTO coverage_master (coverage_name, coverage_group)
VALUES (%s, %s)
ON DUPLICATE KEY UPDATE
    coverage_group = VALUES(coverage_group)
"""

data_to_insert = [
    ('대인배상1', '인담보'),
    ('대인배상2', '인담보'),
    ('자기신체사고', '인담보'),
    ('대물배상', '물담보'),
    ('자기차량손해', '물담보')
]

cursor.executemany(insert_sql, data_to_insert)
conn.commit()

print(f"{cursor.rowcount}건 처리 완료")

cursor.execute("SELECT * FROM coverage_master")
for row in cursor.fetchall():
    print(row)

cursor.close()
conn.close()
# Out:
# 5건 처리 완료
# (1, '대인배상1', '인담보')
# (2, '대인배상2', '인담보')
# (3, '자기신체사고', '인담보')
# (4, '대물배상', '물담보')
# (5, '자기차량손해', '물담보')
